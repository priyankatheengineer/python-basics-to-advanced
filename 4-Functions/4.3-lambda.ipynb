# %%
addition=lambda a,b:a+b
type(addition)
print(addition(5,6))
# Out:
# 11

# %%
even1=lambda num:num%2==0

even1(12)
# Out:
# True

# %%
addition1=lambda x,y,z: x+y+z
print(addition1(4,5,1))
# Out:
# 10

# %%
## map()

numbers=[1,2,3,4,5,6]

list(map(lambda x:x**2, numbers))
# Out:
# [1, 4, 9, 16, 25, 36]

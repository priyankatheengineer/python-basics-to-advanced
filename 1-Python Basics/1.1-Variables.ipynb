# %%
## declaring and assigning variables
age=32
height=6.1
name="krish"
is_student=True

## printing the variables

print("age: ", age)
print("hight: ",height)
print("name: ",name)
# Out:
# age:  32
# hight:  6.1
# name:  krish

# %%
## naming conventions
## Variable names should be descriptive
## They must start with a letter or an '-' and containes letter, numbers and underscores

#valid variable names

first_name="krish"
last_name="naitik"

# %%
# Invalid variable names
# 2age=30
# first-name="Krish"
# @name="Rohit"

# %%
## understanding variable types
## Python is dynamically typed - type of a variable at run time
age=25 #int
height=6.1  #float
name="Krish" #str
is_student = True #bool

print(type(name))
# Out:
# <class 'str'>

# %%
age='25'
print(int(age))
print(type(int(age)))
# Out:
# 25
# <class 'int'>

# %%
name="Krish"
# error - int(name)

# %%
height=5.11
type(height)

print(int(height))
print(float(height))
# Out:
# 5
# 5.11

# %%
## Dynamic Typing
## Python allows the type of variable to change as the program executes
var=10 #int
print(var,type(var))
var="Hello"
print(var,type(var))
var=3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %%
## input

age=input("What is the age?")
print(age,type(age))
# Out:
# 24 <class 'str'>

# %%
## Simple calculator
num1=float(input("Enter first number: "))
num2=float(input("Enter second number: "))

sum = num1+num2
subtract = num1-num2
product = num1*num2
quotient=num1/num2

print("Addition: ",sum)
print("Subtraction: ",subtract)
print("Product: ",product)
print("Quotient: ",quotient)
# Out:
# Addition:  88.0
# Subtraction:  42.0
# Product:  1495.0
# Quotient:  2.8260869565217392

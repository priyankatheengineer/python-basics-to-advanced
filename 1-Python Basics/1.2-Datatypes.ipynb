# %%
## Integer Example
age=35
type(age)
# Out:
# int

# %%
## Floating point datatype
height=5.11
type(height)
# Out:
# float

# %%
## String Datatype Example
name="Krish"
print(name)
print(type(name))
# Out:
# Krish
# <class 'str'>

# %%
## boolean datatype
is_student = True
type(is_student)
is_student = False
type(is_student)
# Out:
# bool

# %%
bool()
# Out:
# False

# %%
a=10
b=10
type(a==b)
# Out:
# bool

# %%
## common errors

result="Hello" + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 ## common errors
# ----> 3 result="Hello"+5
#
# TypeError: can only concatenate str (not "int") to str

# %%
result = "Hello" + str(5)
print(result)
# Out:
# Hello5

# %%
str="Hello"
str.isalnum
# Out:
# <built-in method isalnum of str object at 0x0000015B16317720>

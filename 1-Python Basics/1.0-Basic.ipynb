# %%
## Basic syntax Rules in Python
## Case Sensitivity - Python is case sensitive
name="krish"
Name="Naitik"

print(name)
print(Name)
# Out:
# krish
# Naitik

# %%
## Indentation
## Python uses indentation to define blocks of code. Consistent use of spaces (commonly 4) or a tab is required.abs

age=32
if age > 30:
    print(age)
# Out:
# 32

# %%
## Line continuation  - use backslash
total=1+2+3+4+5+6+7+\
8+9
print(total)
# Out:
# 45

# %%
## Multiple statements on a single line
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
## Understanding symantics in python
# variable assignment
age=32 ## age is an integer
name="krish" ## name is a string

# %%
## Type inference
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## Type Inference
variable=10
print(type(variable))
variable="Krish"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>
